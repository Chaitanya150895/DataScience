# %%
import numpy as numpy
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
df = pd.read_csv("C:\\Users\\91820\\Downloads\\archive (3)\AirPassengers.csv", parse_dates = ['Month'], index_col = 'Month')

# %%
df.dtypes
# Out:
# #Passengers    int64
# dtype: object

# %%
df.head()
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121

# %%
df['1951-04-01':'1952-03-01']
# Out:
#             #Passengers
# Month
# 1951-04-01          163
# 1951-05-01          172
# 1951-06-01          178
# 1951-07-01          199
# 1951-08-01          199
# 1951-09-01          184
# 1951-10-01          162
# 1951-11-01          146
# 1951-12-01          166
# 1952-01-01          171
# 1952-02-01          180
# 1952-03-01          193

# %%
df.loc['1960-05-01']
# Out:
# #Passengers    472
# Name: 1960-05-01 00:00:00, dtype: int64

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 12,8
df.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
df_mul_decompose = seasonal_decompose(df,model="multplicative")
df_mul_decompose.plot()

# %%
import numpy as np
df = pd.read_csv("C:\\Users\\91820\\Downloads\\archive (3)\AirPassengers.csv", parse_dates = ['Month'], index_col = 'Month')
#log transformation
df_log = df.copy()
df_log['Passengers'] = np.log(df)

# %%
df_log.Passengers
# Out:
# Month
# 1949-01-01    4.718499
# 1949-02-01    4.770685
# 1949-03-01    4.882802
# 1949-04-01    4.859812
# 1949-05-01    4.795791
#                 ...
# 1960-08-01    6.406880
# 1960-09-01    6.230481
# 1960-10-01    6.133398
# 1960-11-01    5.966147
# 1960-12-01    6.068426
# Name: Passengers, Length: 144, dtype: float64

# %%
df_log.plot()
# Out:
# <AxesSubplot:xlabel='Month'>
